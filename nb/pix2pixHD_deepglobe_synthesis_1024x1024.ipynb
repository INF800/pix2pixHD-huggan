LmFecfJvZFoWWXWHYHzNo35ARWCxlPF5awhkE_ALMJJ9M1sf0wiY3xFhoAexrlVZTnhTErPHaGdFoCnAqZQKXoxUcEqCfr9NR0zALJ1Hkox9JsvoyKckXXbQS75jIFYx0FAITKsatmUpzktpYwQGMD1qB7RLs3pMio3HpclaPbz0ej4TQ0SPI-9Gq.8iY-sztH7R50mnJkQhTC2A/pix2pixHD-deepglobe-synthesis.zip
# Resolving www.kaggleusercontent.com (www.kaggleusercontent.com)... 35.190.26.106
# ...

# %%
# grab packages and source code
! pip install --upgrade --no-cache-dir dominate gdown -qqq
# !git clone https://github.com/NVIDIA/pix2pixHD
# %cd pix2pixHD
# download model weights
# !gdown https://drive.google.com/uc?id=1h9SykUnuZul7J3Nbms2QGH1wa85nbN2-
# !mkdir checkpoints/
# !mkdir checkpoints/label2city_1024p/
# !mv latest_net_G.pth ./checkpoints/label2city_1024p/
# Out:
# Cloning into 'pix2pixHD'...
# remote: Enumerating objects: 340, done.
# remote: Total 340 (delta 0), reused 0 (delta 0), pack-reused 340
# Receiving objects: 100% (340/340), 55.68 MiB | 17.48 MiB/s, done.
# Resolving deltas: 100% (156/156), done.
# /notebooks/pix2pixHD
# Downloading...
# From: https://drive.google.com/uc?id=1h9SykUnuZul7J3Nbms2QGH1wa85nbN2-
# To: /notebooks/pix2pixHD/latest_net_G.pth
# 100%|████████████████████████████████████████| 732M/732M [00:31<00:00, 23.2MB/s]

# %%
# %cd ./pix2pixHD
# !python train.py --no_instance --name label2sat_2448p --batchSize 1 --label_nc 7 --niter 50  --niter_decay 50  --dataroot ../pix2pixHD-deepglobe-synthesis
# Out:
# /notebooks/pix2pixHD
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: ../pix2pixHD-deepglobe-synthesis
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 7
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: label2sat_2448p
# ndf: 64
# nef: 16
# netG: global
# ngf: 64
# niter: 50
# niter_decay: 50
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# ...

# %%
# %cd ./pix2pixHD
# !python test.py --no_instance --name label2sat_2448p --batchSize 1 --label_nc 7 --dataroot ../pix2pixHD-deepglobe-synthesis
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ../pix2pixHD-deepglobe-synthesis
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 50
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 7
# loadSize: 1024
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: label2sat_2448p
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# no_instance: True
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# resize_or_crop: scale_width
# results_dir: ./results/
# serial_batches: False
# tf_log: False
# use_dropout: False
# ...

# %%
""" download images """
# !ls  ./checkpoints/label2sat_2448p/web/images
# !ls  ./results/label2sat_2448p/test_latest/images
# !zip -r ../out.ep10.train.zip ./checkpoints/label2sat_2448p/web/images
# !zip -r ../out.ep10.test.zip ./results/label2sat_2448p/test_latest/images
# Out:
# updating: checkpoints/label2sat_2448p/web/images/ (stored 0%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch002_real_image.jpg (deflated 1%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch012_input_label.jpg (deflated 42%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch006_input_label.jpg (deflated 30%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch004_real_image.jpg (deflated 0%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch007_input_label.jpg (deflated 68%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch012_real_image.jpg (deflated 0%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch001_input_label.jpg (deflated 25%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch004_input_label.jpg (deflated 69%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch009_synthesized_image.jpg (deflated 13%)
#   adding: checkpoints/label2sat_2448p/web/images/epoch004_synthesized_image.jpg (deflated 61%)
# ...
